# %%
#Data Augmentation and Dropout

# !pip install kaggle
from google.colab import files
files.upload()
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (1.5.12)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle) (5.0.2)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle) (2021.10.8)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle) (4.62.3)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (2.10)
#      <input type="file" id="files-f80b99c9-a598-4678-a465-6b8b93411354" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f80b99c9-a598-4678-a465-6b8b93411354">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"isaac000o","key":"2c1a236c98c03c0ce703259671092452"}'}

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle datasets download -d legendahmed/alzheimermridataset
# Out:
# Downloading alzheimermridataset.zip to /content
#  86% 53.0M/61.8M [00:01<00:00, 29.8MB/s]
# 100% 61.8M/61.8M [00:01<00:00, 44.1MB/s]

# %%
from zipfile import ZipFile
filename = "alzheimermridataset.zip"

with ZipFile(filename,'r') as zip:
  print("Extracting of the file ...")
  zip.extractall()
  print("Done")
# Out:
# Extracting of the file ...
# Done

# %%
#libraries 
from imutils import paths
import cv2
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Dropout, Flatten, Dense, MaxPool2D
from tensorflow.keras.models import Model, Sequential

from tensorflow.keras.optimizers import Adam, SGD

# %%
Training_images_paths = list(paths.list_images("/content/Alzheimer_s Dataset/train"))
Training_labels = []
Training_images = []

i = 0 
while i < len(Training_images_paths):
  Training_labels.append(Training_images_paths[i].split("/")[4])
  image = cv2.imread(Training_images_paths[i])
  image = cv2.resize(image,(256,256))
  Training_images.append(image)
  i = i + 1



print("Number of Images:",len(Training_labels))
cv2_imshow(Training_images[0])
# Out:
# Number of Images: 5121
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F2CC7D93FD0>

# %%
Testing_images_paths = list(paths.list_images("/content/Alzheimer_s Dataset/test"))
Testing_labels = []
Testing_images = []

i = 0 
while i < len(Testing_images_paths):
  Testing_labels.append(Testing_images_paths[i].split("/")[4])
  image = cv2.imread(Testing_images_paths[i])
  image = cv2.resize(image,(256,256))
  Testing_images.append(image)
  i = i + 1



print("Number of Images:",len(Testing_labels))
cv2_imshow(Testing_images[0])
# Out:
# Number of Images: 1279
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F2D615E3A10>

# %%
Mild_count = 0
Moderate_count = 0
Non_count = 0
VeryMild_count = 0
count = 0
for i in Training_labels:
  if i =="MildDemented":
    Mild_count = Mild_count + 1
  elif i =="ModerateDemented":
    Moderate_count = Moderate_count + 1
  elif i == "NonDemented":
    Non_count = Non_count + 1
  elif i == "VeryMildDemented":
    VeryMild_count = VeryMild_count +1 
  count = count + 1
print("MildDemented:{},ModerateDemented:{},NonDemented:{},VeryMildDemented:{}, Total:{}".format(Mild_count,Moderate_count,Non_count,VeryMild_count,count))
# Out:
# MildDemented:717,ModerateDemented:52,NonDemented:2560,VeryMildDemented:1792, Total:5121

# %%
Mild_count = 0
Moderate_count = 0
Non_count = 0
VeryMild_count = 0
count = 0
for i in Testing_labels:
  if i =="MildDemented":
    Mild_count = Mild_count + 1
  elif i =="ModerateDemented":
    Moderate_count = Moderate_count + 1
  elif i == "NonDemented":
    Non_count = Non_count + 1
  elif i == "VeryMildDemented":
    VeryMild_count = VeryMild_count +1 
  count = count + 1
print("MildDemented:{},ModerateDemented:{},NonDemented:{},VeryMildDemented:{}, Total:{}".format(Mild_count,Moderate_count,Non_count,VeryMild_count,count))
# Out:
# MildDemented:179,ModerateDemented:12,NonDemented:640,VeryMildDemented:448, Total:1279

# %%
"""
A balanced multiclass data is prepared for classification by using data augmentation 
for the class which has smaller number of images to get balanced with other classes. 
Augmentation is done by simply flipping the image along horizontal axis. 
This operation is valid because of the left and right symmetry of brain regions. 
The balanced set includes a total of 9506 images for each class, and a total of 38024 images for all classes.
@INPROCEEDINGS{8261460,
  author={Farooq, Ammarah and Anwar, SyedMuhammad and Awais, Muhammad and Rehman, Saad},
  booktitle={2017 IEEE International Conference on Imaging Systems and Techniques (IST)}, 
  title={A deep CNN based multi-class classification of Alzheimer's disease using MRI}, 
  year={2017},
  volume={},
  number={},
  pages={1-6},
  doi={10.1109/IST.2017.8261460}}
"""
data_generator = ImageDataGenerator(horizontal_flip=True)

# %%
Training_images_np = np.array(Training_images) 
Training_labels_np = np.array(Training_labels)

Testing_images_np = np.array(Testing_images) 
Testing_labels_np = np.array(Testing_labels)

# %%
aug_traning_images_VeryMildDemented = []
aug_traning_labels_VeryMildDemented = []
v = 0 
while v < 1792:
  traning_image = Training_images_np[v]
  traning_image = traning_image.reshape((1,)+traning_image.shape)
  it = data_generator.flow(traning_image,batch_size=1,shuffle=True)

  for i in range(3):
    batch = it.next()
    aug_traning_image = batch[0].astype('uint8') 
    aug_traning_images_VeryMildDemented.append(aug_traning_image)
    aug_traning_labels_VeryMildDemented.append(Training_labels[v])
  v = v+1

print(len(aug_traning_labels_VeryMildDemented))
# Out:
# 5376

# %%
aug_traning_images_ModerateDemented = []
aug_traning_labels_ModerateDemented = []

v = 1792 
while v < 1844:
  traning_image = Training_images_np[v]
  traning_image = traning_image.reshape((1,)+traning_image.shape)
  it = data_generator.flow(traning_image,batch_size=1,shuffle=True)

  for i in range(100):
    batch = it.next()
    aug_traning_image = batch[0].astype('uint8') 
    aug_traning_images_ModerateDemented.append(aug_traning_image)
    aug_traning_labels_ModerateDemented.append(Training_labels[v])
  v = v+1
print(len(aug_traning_labels_ModerateDemented))
# Out:
# 5200

# %%
aug_traning_images_NonDemented = []
aug_traning_labels_NonDemented = []

v = 1844 
while v < 4404:
  traning_image = Training_images_np[v]
  traning_image = traning_image.reshape((1,)+traning_image.shape)
  it = data_generator.flow(traning_image,batch_size=1,shuffle=True)

  for i in range(2):
    batch = it.next()
    aug_traning_image = batch[0].astype('uint8') 
    aug_traning_images_NonDemented.append(aug_traning_image)
    aug_traning_labels_NonDemented.append(Training_labels[v])
  v = v+1



print(len(aug_traning_labels_NonDemented))
# Out:
# 5120

# %%
aug_traning_images_MildDemented = []
aug_traning_labels_MildDemented = []

v = 4404 
while v < len(Training_labels):
  traning_image = Training_images_np[v]
  traning_image = traning_image.reshape((1,)+traning_image.shape)
  it = data_generator.flow(traning_image,batch_size=1,shuffle=True)

  for i in range(8):
    batch = it.next()
    aug_traning_image = batch[0].astype('uint8') 
    aug_traning_images_MildDemented.append(aug_traning_image)
    aug_traning_labels_MildDemented.append(Training_labels[v])
  v = v+1


print(len(aug_traning_labels_MildDemented))
# Out:
# 5736

# %%
aug_traning_images = aug_traning_images_MildDemented + aug_traning_images_NonDemented + aug_traning_images_ModerateDemented + aug_traning_images_VeryMildDemented+Training_images
aug_traning_labels = aug_traning_labels_MildDemented + aug_traning_labels_NonDemented + aug_traning_labels_ModerateDemented + aug_traning_labels_VeryMildDemented+Training_labels

print(len(aug_traning_images))
print(len(aug_traning_labels))
# Out:
# 26553
# 26553

# %%
aug_testing_images_VeryMildDemented = []
aug_testing_labels_VeryMildDemented = []
x = 0 
while x < 448:
  testing_image = Testing_images_np[x]
  testing_image = testing_image.reshape((1,)+testing_image.shape)
  it = data_generator.flow(testing_image,batch_size=1,shuffle=True)

  for i in range(9):
    batch = it.next()
    aug_testing_image = batch[0].astype('uint8') 
    aug_testing_images_VeryMildDemented.append(aug_testing_image)
    aug_testing_labels_VeryMildDemented.append(Testing_labels[x])
  x = x+1

print(len(aug_testing_labels_VeryMildDemented))
# Out:
# 4032

# %%
aug_testing_images_ModerateDemented = []
aug_testing_labels_ModerateDemented = []
x = 448 
while x < 460:
  testing_image = Testing_images_np[x]
  testing_image = testing_image.reshape((1,)+testing_image.shape)
  it = data_generator.flow(testing_image,batch_size=1,shuffle=True)

  for i in range(400):
    batch = it.next()
    aug_testing_image = batch[0].astype('uint8') 
    aug_testing_images_ModerateDemented.append(aug_testing_image)
    aug_testing_labels_ModerateDemented.append(Testing_labels[x])
  x = x+1

print(len(aug_testing_labels_ModerateDemented))
# Out:
# 4800

# %%
aug_testing_images_NonDemented = []
aug_testing_labels_NonDemented = []
x = 460 
while x < 1100:
  testing_image = Testing_images_np[x]
  testing_image = testing_image.reshape((1,)+testing_image.shape)
  it = data_generator.flow(testing_image,batch_size=1,shuffle=True)

  for i in range(8):
    batch = it.next()
    aug_testing_image = batch[0].astype('uint8') 
    aug_testing_images_NonDemented.append(aug_testing_image)
    aug_testing_labels_NonDemented.append(Testing_labels[x])
  x = x+1

print(len(aug_testing_labels_NonDemented))
# Out:
# 5120

# %%
aug_testing_images_MildDemented = []
aug_testing_labels_MildDemented = []
x = 1100 

while x < len(Testing_labels):
  testing_image = Testing_images_np[x]
  testing_image = testing_image.reshape((1,)+testing_image.shape)
  it = data_generator.flow(testing_image,batch_size=1,shuffle=True)
  #130
  for i in range(30):
    batch = it.next()
    aug_testing_image = batch[0].astype('uint8') 
    aug_testing_images_MildDemented.append(aug_testing_image)
    aug_testing_labels_MildDemented.append(Testing_labels[x])
  x = x+1

print(len(aug_testing_labels_MildDemented))
# Out:
# 5370

# %%
aug_testing_images = aug_testing_images_MildDemented + aug_testing_images_NonDemented + aug_testing_images_ModerateDemented + aug_testing_images_VeryMildDemented + Testing_images
aug_testing_labels = aug_testing_labels_MildDemented + aug_testing_labels_NonDemented + aug_testing_labels_ModerateDemented + aug_testing_labels_VeryMildDemented + Testing_labels

print(len(aug_testing_images))
print(len(aug_testing_labels))
# Out:
# 20601
# 20601

# %%
i = 0 
while i <len(aug_traning_images):
  image = aug_traning_images[i]
  image = cv2.resize(image,(128,128))
  image = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
  aug_traning_images[i] = image
  i = i + 1


n = 0 
while n < len(aug_testing_images):
  image = aug_testing_images[n]
  image = cv2.resize(image,(128,128))
  image = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
  aug_testing_images[n] = image
  n = n + 1

print(type(aug_traning_images))
aug_traning_images = np.array(aug_traning_images)
aug_testing_images = np.array(aug_testing_images)
print(type(aug_traning_images))


aug_traning_images = aug_traning_images/255.00
aug_testing_images = aug_testing_images/255.00

label_encoder = LabelEncoder()

aug_traning_labels = label_encoder.fit_transform(aug_traning_labels)
print(aug_traning_labels.shape)

label_encoder = LabelEncoder()
aug_testing_labels = label_encoder.fit_transform(aug_testing_labels)
print(aug_testing_labels.shape)

aug_traning_labels = to_categorical(aug_traning_labels)
aug_testing_labels = to_categorical(aug_testing_labels)

aug_traning_images = np.expand_dims(aug_traning_images, axis=-1)
aug_testing_images = np.expand_dims(aug_testing_images, axis=-1)


print(aug_traning_images.shape)
print(aug_traning_labels.shape)
print(aug_testing_images.shape)
print(aug_testing_labels.shape)
# Out:
# <class 'list'>
# <class 'numpy.ndarray'>
# (26553,)
# (20601,)
# (26553, 128, 128, 1)
# (26553, 4)
# (20601, 128, 128, 1)
# (20601, 4)

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 54.8 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
def Alzheimer_Data_Augmentation(input_shape=(128, 128, 1)):
    model = Sequential()
    model.add(Input(shape=input_shape))
    model.add(Conv2D(128, (5, 5), padding='same', strides=(1, 1), name='conv1', activation='relu'))
    model.add(MaxPool2D((9, 9), strides=(3, 3)))
    model.add(Conv2D(64, (5, 5), padding='same', strides=(1, 1), name='conv2', activation='relu'))
    model.add(MaxPool2D((7, 7), strides=(3, 3)))
    model.add(Conv2D(32, (3, 3), padding='same', strides=(1, 1), name='conv3', activation='relu'))
    model.add(MaxPool2D((5, 5), strides=(2, 2)))
    model.add(Conv2D(32, (3, 3), padding='same', strides=(1, 1), name='conv4', activation='relu'))
    model.add(MaxPool2D((3, 3), strides=(2, 2)))    
    
    model.add(Flatten())
    model.add(Dropout(0.5))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(4, activation='softmax'))
    optimizer = Adam(3.15e-5)
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

model= Alzheimer_Data_Augmentation(input_shape=(128, 128, 1))
model.summary()

hist_ = model.fit(aug_traning_images, aug_traning_labels, batch_size=128, epochs=200, validation_data=(aug_testing_images, aug_testing_labels))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1 (Conv2D)              (None, 128, 128, 128)     3328
#
#  max_pooling2d (MaxPooling2D  (None, 40, 40, 128)      0
#  )
#
#  conv2 (Conv2D)              (None, 40, 40, 64)        204864
#
#  max_pooling2d_1 (MaxPooling  (None, 12, 12, 64)       0
#  2D)
#
#  conv3 (Conv2D)              (None, 12, 12, 32)        18464
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 32)         0
#  2D)
#
#  conv4 (Conv2D)              (None, 4, 4, 32)          9248
#
#  max_pooling2d_3 (MaxPooling  (None, 1, 1, 32)         0
#  2D)
#
#  flatten (Flatten)           (None, 32)                0
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense (Dense)               (None, 64)                2112
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 238,276
# Trainable params: 238,276
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 208/208 [==============================] - 34s 122ms/step - loss: 1.3311 - accuracy: 0.3604 - val_loss: 1.2223 - val_accuracy: 0.4708
# Epoch 2/200
# 208/208 [==============================] - 23s 111ms/step - loss: 1.2637 - accuracy: 0.3809 - val_loss: 1.1702 - val_accuracy: 0.4708
# Epoch 3/200
# 208/208 [==============================] - 23s 111ms/step - loss: 1.2289 - accuracy: 0.3969 - val_loss: 1.1327 - val_accuracy: 0.4708
# Epoch 4/200
# 208/208 [==============================] - 23s 111ms/step - loss: 1.1984 - accuracy: 0.4148 - val_loss: 1.0826 - val_accuracy: 0.4708
# Epoch 5/200
# 208/208 [==============================] - 23s 111ms/step - loss: 1.1564 - accuracy: 0.4330 - val_loss: 1.0038 - val_accuracy: 0.5785
# Epoch 6/200
# 208/208 [==============================] - 23s 111ms/step - loss: 1.1090 - accuracy: 0.4687 - val_loss: 0.9456 - val_accuracy: 0.6209
# Epoch 7/200
# 208/208 [==============================] - 23s 111ms/step - loss: 1.0707 - accuracy: 0.4900 - val_loss: 0.9242 - val_accuracy: 0.6384
# Epoch 8/200
# 208/208 [==============================] - 23s 111ms/step - loss: 1.0502 - accuracy: 0.5007 - val_loss: 0.9076 - val_accuracy: 0.6351
# Epoch 9/200
# 208/208 [==============================] - 23s 111ms/step - loss: 1.0239 - accuracy: 0.5168 - val_loss: 0.8991 - val_accuracy: 0.6400
# Epoch 10/200
# 208/208 [==============================] - 23s 111ms/step - loss: 1.0121 - accuracy: 0.5196 - val_loss: 0.8919 - val_accuracy: 0.6416
# Epoch 11/200
# 208/208 [==============================] - 23s 111ms/step - loss: 1.0012 - accuracy: 0.5252 - val_loss: 0.8831 - val_accuracy: 0.6387
# Epoch 12/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.9854 - accuracy: 0.5338 - val_loss: 0.8845 - val_accuracy: 0.6452
# Epoch 13/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.9808 - accuracy: 0.5365 - val_loss: 0.8869 - val_accuracy: 0.6361
# Epoch 14/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.9664 - accuracy: 0.5482 - val_loss: 0.8845 - val_accuracy: 0.6504
# Epoch 15/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.9567 - accuracy: 0.5511 - val_loss: 0.8706 - val_accuracy: 0.6405
# Epoch 16/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.9427 - accuracy: 0.5593 - val_loss: 0.8746 - val_accuracy: 0.6499
# Epoch 17/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.9373 - accuracy: 0.5633 - val_loss: 0.8702 - val_accuracy: 0.6556
# Epoch 18/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.9207 - accuracy: 0.5734 - val_loss: 0.8681 - val_accuracy: 0.6656
# Epoch 19/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.9145 - accuracy: 0.5807 - val_loss: 0.8690 - val_accuracy: 0.6500
# Epoch 20/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.9020 - accuracy: 0.5884 - val_loss: 0.8749 - val_accuracy: 0.6638
# Epoch 21/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.8911 - accuracy: 0.5938 - val_loss: 0.8600 - val_accuracy: 0.6718
# Epoch 22/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.8795 - accuracy: 0.6033 - val_loss: 0.8625 - val_accuracy: 0.6592
# Epoch 23/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.8714 - accuracy: 0.6112 - val_loss: 0.8665 - val_accuracy: 0.6707
# Epoch 24/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.8591 - accuracy: 0.6186 - val_loss: 0.8721 - val_accuracy: 0.6731
# Epoch 25/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.8521 - accuracy: 0.6186 - val_loss: 0.8640 - val_accuracy: 0.6629
# Epoch 26/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.8427 - accuracy: 0.6261 - val_loss: 0.9003 - val_accuracy: 0.6131
# Epoch 27/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.8353 - accuracy: 0.6327 - val_loss: 0.8773 - val_accuracy: 0.6586
# Epoch 28/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.8133 - accuracy: 0.6381 - val_loss: 0.9361 - val_accuracy: 0.5909
# Epoch 29/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.8097 - accuracy: 0.6405 - val_loss: 0.8892 - val_accuracy: 0.6260
# Epoch 30/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.8007 - accuracy: 0.6460 - val_loss: 0.8991 - val_accuracy: 0.6234
# Epoch 31/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.7880 - accuracy: 0.6519 - val_loss: 0.9105 - val_accuracy: 0.6158
# Epoch 32/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.7808 - accuracy: 0.6571 - val_loss: 0.9102 - val_accuracy: 0.6157
# Epoch 33/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.7717 - accuracy: 0.6608 - val_loss: 0.9021 - val_accuracy: 0.6290
# Epoch 34/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.7587 - accuracy: 0.6647 - val_loss: 0.9171 - val_accuracy: 0.6030
# Epoch 35/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.7500 - accuracy: 0.6665 - val_loss: 0.9372 - val_accuracy: 0.5905
# Epoch 36/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.7478 - accuracy: 0.6704 - val_loss: 0.9381 - val_accuracy: 0.5908
# Epoch 37/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.7359 - accuracy: 0.6735 - val_loss: 1.0647 - val_accuracy: 0.5384
# Epoch 38/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.7304 - accuracy: 0.6788 - val_loss: 0.9217 - val_accuracy: 0.6100
# Epoch 39/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.7189 - accuracy: 0.6803 - val_loss: 0.9562 - val_accuracy: 0.5899
# Epoch 40/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.7117 - accuracy: 0.6863 - val_loss: 0.9644 - val_accuracy: 0.6015
# Epoch 41/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.6982 - accuracy: 0.6913 - val_loss: 0.9435 - val_accuracy: 0.5981
# Epoch 42/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.6932 - accuracy: 0.6899 - val_loss: 1.0112 - val_accuracy: 0.5681
# Epoch 43/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.6889 - accuracy: 0.6948 - val_loss: 0.9666 - val_accuracy: 0.6013
# Epoch 44/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.6778 - accuracy: 0.6966 - val_loss: 1.0934 - val_accuracy: 0.4795
# Epoch 45/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.6770 - accuracy: 0.7000 - val_loss: 0.9736 - val_accuracy: 0.5742
# Epoch 46/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.6643 - accuracy: 0.7039 - val_loss: 0.9854 - val_accuracy: 0.5926
# Epoch 47/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.6526 - accuracy: 0.7076 - val_loss: 0.9290 - val_accuracy: 0.6332
# Epoch 48/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.6429 - accuracy: 0.7088 - val_loss: 0.9223 - val_accuracy: 0.6380
# Epoch 49/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.6432 - accuracy: 0.7113 - val_loss: 0.9417 - val_accuracy: 0.6084
# Epoch 50/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.6343 - accuracy: 0.7150 - val_loss: 0.9687 - val_accuracy: 0.5807
# Epoch 51/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.6209 - accuracy: 0.7205 - val_loss: 1.0643 - val_accuracy: 0.5533
# Epoch 52/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.6213 - accuracy: 0.7195 - val_loss: 1.0124 - val_accuracy: 0.5691
# Epoch 53/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.6075 - accuracy: 0.7253 - val_loss: 0.9751 - val_accuracy: 0.5896
# Epoch 54/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.6051 - accuracy: 0.7287 - val_loss: 1.0704 - val_accuracy: 0.5725
# Epoch 55/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.5942 - accuracy: 0.7319 - val_loss: 1.0299 - val_accuracy: 0.5772
# Epoch 56/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.5954 - accuracy: 0.7305 - val_loss: 1.1154 - val_accuracy: 0.5222
# Epoch 57/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.5866 - accuracy: 0.7357 - val_loss: 1.0513 - val_accuracy: 0.5765
# Epoch 58/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.5823 - accuracy: 0.7367 - val_loss: 1.0217 - val_accuracy: 0.5775
# Epoch 59/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.5745 - accuracy: 0.7392 - val_loss: 0.9809 - val_accuracy: 0.5958
# Epoch 60/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.5723 - accuracy: 0.7411 - val_loss: 0.9516 - val_accuracy: 0.5841
# Epoch 61/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.5682 - accuracy: 0.7476 - val_loss: 1.0617 - val_accuracy: 0.5769
# Epoch 62/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.5624 - accuracy: 0.7438 - val_loss: 1.0192 - val_accuracy: 0.5725
# Epoch 63/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.5534 - accuracy: 0.7502 - val_loss: 0.9984 - val_accuracy: 0.5854
# Epoch 64/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.5519 - accuracy: 0.7550 - val_loss: 0.9987 - val_accuracy: 0.5890
# Epoch 65/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.5490 - accuracy: 0.7527 - val_loss: 1.0652 - val_accuracy: 0.5755
# Epoch 66/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.5417 - accuracy: 0.7552 - val_loss: 1.0608 - val_accuracy: 0.5731
# Epoch 67/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.5428 - accuracy: 0.7558 - val_loss: 1.1176 - val_accuracy: 0.5522
# Epoch 68/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.5292 - accuracy: 0.7638 - val_loss: 0.9897 - val_accuracy: 0.5991
# Epoch 69/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.5302 - accuracy: 0.7648 - val_loss: 1.0317 - val_accuracy: 0.5769
# Epoch 70/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.5293 - accuracy: 0.7648 - val_loss: 1.0333 - val_accuracy: 0.5802
# Epoch 71/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.5246 - accuracy: 0.7660 - val_loss: 1.0888 - val_accuracy: 0.5855
# Epoch 72/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.5175 - accuracy: 0.7708 - val_loss: 1.0618 - val_accuracy: 0.5744
# Epoch 73/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.5121 - accuracy: 0.7732 - val_loss: 1.1229 - val_accuracy: 0.5569
# Epoch 74/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.5089 - accuracy: 0.7726 - val_loss: 1.0543 - val_accuracy: 0.5881
# Epoch 75/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.4992 - accuracy: 0.7807 - val_loss: 1.0562 - val_accuracy: 0.5818
# Epoch 76/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.5044 - accuracy: 0.7785 - val_loss: 1.0621 - val_accuracy: 0.5821
# Epoch 77/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.4946 - accuracy: 0.7833 - val_loss: 1.1052 - val_accuracy: 0.5478
# Epoch 78/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.4908 - accuracy: 0.7870 - val_loss: 1.0626 - val_accuracy: 0.5842
# Epoch 79/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.4860 - accuracy: 0.7880 - val_loss: 1.1134 - val_accuracy: 0.5892
# Epoch 80/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.4851 - accuracy: 0.7880 - val_loss: 1.0768 - val_accuracy: 0.5834
# Epoch 81/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.4832 - accuracy: 0.7920 - val_loss: 1.1653 - val_accuracy: 0.5673
# Epoch 82/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.4740 - accuracy: 0.7962 - val_loss: 1.1368 - val_accuracy: 0.5668
# Epoch 83/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.4702 - accuracy: 0.7979 - val_loss: 1.0892 - val_accuracy: 0.5935
# Epoch 84/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.4762 - accuracy: 0.7950 - val_loss: 1.1487 - val_accuracy: 0.5539
# Epoch 85/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.4619 - accuracy: 0.8021 - val_loss: 1.0778 - val_accuracy: 0.5973
# Epoch 86/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.4658 - accuracy: 0.7994 - val_loss: 1.1463 - val_accuracy: 0.5802
# Epoch 87/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.4554 - accuracy: 0.8067 - val_loss: 1.1431 - val_accuracy: 0.5667
# Epoch 88/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.4513 - accuracy: 0.8072 - val_loss: 1.0831 - val_accuracy: 0.5678
# Epoch 89/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.4501 - accuracy: 0.8073 - val_loss: 1.2028 - val_accuracy: 0.5711
# Epoch 90/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.4403 - accuracy: 0.8110 - val_loss: 1.1403 - val_accuracy: 0.5782
# Epoch 91/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.4558 - accuracy: 0.8040 - val_loss: 1.1938 - val_accuracy: 0.5662
# Epoch 92/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.4426 - accuracy: 0.8139 - val_loss: 1.1366 - val_accuracy: 0.5770
# Epoch 93/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.4329 - accuracy: 0.8166 - val_loss: 1.2496 - val_accuracy: 0.5686
# Epoch 94/200
# 208/208 [==============================] - 23s 109ms/step - loss: 0.4347 - accuracy: 0.8168 - val_loss: 1.0875 - val_accuracy: 0.5937
# Epoch 95/200
# 208/208 [==============================] - 23s 109ms/step - loss: 0.4295 - accuracy: 0.8190 - val_loss: 1.3260 - val_accuracy: 0.5414
# Epoch 96/200
# 208/208 [==============================] - 23s 109ms/step - loss: 0.4280 - accuracy: 0.8210 - val_loss: 1.1560 - val_accuracy: 0.5886
# Epoch 97/200
# 208/208 [==============================] - 23s 109ms/step - loss: 0.4205 - accuracy: 0.8235 - val_loss: 1.1499 - val_accuracy: 0.5907
# Epoch 98/200
# 208/208 [==============================] - 23s 109ms/step - loss: 0.4194 - accuracy: 0.8250 - val_loss: 1.4156 - val_accuracy: 0.5247
# Epoch 99/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.4146 - accuracy: 0.8282 - val_loss: 1.1205 - val_accuracy: 0.5922
# Epoch 100/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.4091 - accuracy: 0.8312 - val_loss: 1.2324 - val_accuracy: 0.5795
# Epoch 101/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.4034 - accuracy: 0.8350 - val_loss: 1.1615 - val_accuracy: 0.5841
# Epoch 102/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.4016 - accuracy: 0.8334 - val_loss: 1.1327 - val_accuracy: 0.5970
# Epoch 103/200
# 208/208 [==============================] - 23s 109ms/step - loss: 0.3938 - accuracy: 0.8415 - val_loss: 1.2608 - val_accuracy: 0.5873
# Epoch 104/200
# 208/208 [==============================] - 23s 109ms/step - loss: 0.3938 - accuracy: 0.8382 - val_loss: 1.2482 - val_accuracy: 0.5719
# Epoch 105/200
# 208/208 [==============================] - 23s 109ms/step - loss: 0.3921 - accuracy: 0.8378 - val_loss: 1.1855 - val_accuracy: 0.5802
# Epoch 106/200
# 208/208 [==============================] - 23s 109ms/step - loss: 0.3832 - accuracy: 0.8445 - val_loss: 1.2848 - val_accuracy: 0.5972
# Epoch 107/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.3808 - accuracy: 0.8473 - val_loss: 1.1381 - val_accuracy: 0.5868
# Epoch 108/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.3790 - accuracy: 0.8473 - val_loss: 1.2460 - val_accuracy: 0.5890
# Epoch 109/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.3761 - accuracy: 0.8482 - val_loss: 1.3323 - val_accuracy: 0.5632
# Epoch 110/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.3682 - accuracy: 0.8519 - val_loss: 1.3309 - val_accuracy: 0.5601
# Epoch 111/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.3731 - accuracy: 0.8491 - val_loss: 1.2788 - val_accuracy: 0.5624
# Epoch 112/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.3617 - accuracy: 0.8561 - val_loss: 1.2562 - val_accuracy: 0.5754
# Epoch 113/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.3550 - accuracy: 0.8596 - val_loss: 1.3086 - val_accuracy: 0.5604
# Epoch 114/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.3538 - accuracy: 0.8603 - val_loss: 1.3194 - val_accuracy: 0.5674
# Epoch 115/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.3497 - accuracy: 0.8594 - val_loss: 1.3627 - val_accuracy: 0.5752
# Epoch 116/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.3441 - accuracy: 0.8651 - val_loss: 1.2000 - val_accuracy: 0.6012
# Epoch 117/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.3450 - accuracy: 0.8655 - val_loss: 1.2755 - val_accuracy: 0.5899
# Epoch 118/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.3398 - accuracy: 0.8638 - val_loss: 1.3792 - val_accuracy: 0.5819
# Epoch 119/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.3413 - accuracy: 0.8674 - val_loss: 1.3955 - val_accuracy: 0.5668
# Epoch 120/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.3285 - accuracy: 0.8747 - val_loss: 1.3519 - val_accuracy: 0.5767
# Epoch 121/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.3268 - accuracy: 0.8723 - val_loss: 1.3272 - val_accuracy: 0.5690
# Epoch 122/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.3175 - accuracy: 0.8803 - val_loss: 1.4065 - val_accuracy: 0.5841
# Epoch 123/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.3209 - accuracy: 0.8785 - val_loss: 1.4297 - val_accuracy: 0.5610
# Epoch 124/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.3177 - accuracy: 0.8779 - val_loss: 1.4281 - val_accuracy: 0.5663
# Epoch 125/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.3139 - accuracy: 0.8808 - val_loss: 1.4918 - val_accuracy: 0.5691
# Epoch 126/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.3075 - accuracy: 0.8844 - val_loss: 1.4232 - val_accuracy: 0.5968
# Epoch 127/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.3061 - accuracy: 0.8838 - val_loss: 1.4888 - val_accuracy: 0.5805
# Epoch 128/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.3060 - accuracy: 0.8840 - val_loss: 1.4823 - val_accuracy: 0.5781
# Epoch 129/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.2962 - accuracy: 0.8881 - val_loss: 1.5505 - val_accuracy: 0.5585
# Epoch 130/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.2895 - accuracy: 0.8921 - val_loss: 1.4294 - val_accuracy: 0.5990
# Epoch 131/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.2901 - accuracy: 0.8907 - val_loss: 1.4475 - val_accuracy: 0.5870
# Epoch 132/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.2894 - accuracy: 0.8922 - val_loss: 1.4403 - val_accuracy: 0.5902
# Epoch 133/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.2826 - accuracy: 0.8956 - val_loss: 1.4514 - val_accuracy: 0.5945
# Epoch 134/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.2871 - accuracy: 0.8932 - val_loss: 1.4310 - val_accuracy: 0.6102
# Epoch 135/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.2779 - accuracy: 0.8967 - val_loss: 1.6062 - val_accuracy: 0.5596
# Epoch 136/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.2846 - accuracy: 0.8926 - val_loss: 1.5985 - val_accuracy: 0.5612
# Epoch 137/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.2706 - accuracy: 0.9005 - val_loss: 1.4745 - val_accuracy: 0.5909
# Epoch 138/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.2604 - accuracy: 0.9048 - val_loss: 1.5882 - val_accuracy: 0.5651
# Epoch 139/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.2654 - accuracy: 0.9014 - val_loss: 1.4629 - val_accuracy: 0.5890
# Epoch 140/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.2575 - accuracy: 0.9044 - val_loss: 1.5473 - val_accuracy: 0.5829
# Epoch 141/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.2588 - accuracy: 0.9068 - val_loss: 1.6809 - val_accuracy: 0.5569
# Epoch 142/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.2569 - accuracy: 0.9075 - val_loss: 1.5999 - val_accuracy: 0.5971
# Epoch 143/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.2635 - accuracy: 0.9013 - val_loss: 1.6950 - val_accuracy: 0.5622
# Epoch 144/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.2637 - accuracy: 0.9020 - val_loss: 1.6383 - val_accuracy: 0.5619
# Epoch 145/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.2426 - accuracy: 0.9139 - val_loss: 1.6261 - val_accuracy: 0.6108
# Epoch 146/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.2426 - accuracy: 0.9123 - val_loss: 1.7718 - val_accuracy: 0.5612
# Epoch 147/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.2366 - accuracy: 0.9160 - val_loss: 1.6106 - val_accuracy: 0.5717
# Epoch 148/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.2385 - accuracy: 0.9124 - val_loss: 1.7408 - val_accuracy: 0.5761
# Epoch 149/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.2344 - accuracy: 0.9149 - val_loss: 1.5841 - val_accuracy: 0.6010
# Epoch 150/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.2292 - accuracy: 0.9184 - val_loss: 1.8682 - val_accuracy: 0.5614
# Epoch 151/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.2268 - accuracy: 0.9205 - val_loss: 1.5796 - val_accuracy: 0.6213
# Epoch 152/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.2213 - accuracy: 0.9228 - val_loss: 1.7823 - val_accuracy: 0.6006
# Epoch 153/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.2211 - accuracy: 0.9216 - val_loss: 1.7784 - val_accuracy: 0.6149
# Epoch 154/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.2156 - accuracy: 0.9248 - val_loss: 1.7776 - val_accuracy: 0.5992
# Epoch 155/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.2187 - accuracy: 0.9224 - val_loss: 1.7006 - val_accuracy: 0.6061
# Epoch 156/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.2138 - accuracy: 0.9239 - val_loss: 1.8788 - val_accuracy: 0.5572
# Epoch 157/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.2120 - accuracy: 0.9254 - val_loss: 1.7048 - val_accuracy: 0.5862
# Epoch 158/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.2061 - accuracy: 0.9289 - val_loss: 1.5670 - val_accuracy: 0.5745
# Epoch 159/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.2113 - accuracy: 0.9263 - val_loss: 1.8861 - val_accuracy: 0.5731
# Epoch 160/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.1952 - accuracy: 0.9322 - val_loss: 2.0700 - val_accuracy: 0.5580
# Epoch 161/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.2025 - accuracy: 0.9290 - val_loss: 1.7390 - val_accuracy: 0.5942
# Epoch 162/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.1973 - accuracy: 0.9310 - val_loss: 1.8430 - val_accuracy: 0.5677
# Epoch 163/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.1951 - accuracy: 0.9309 - val_loss: 1.8905 - val_accuracy: 0.5656
# Epoch 164/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.1982 - accuracy: 0.9316 - val_loss: 1.8001 - val_accuracy: 0.5751
# Epoch 165/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.1896 - accuracy: 0.9353 - val_loss: 2.1914 - val_accuracy: 0.5616
# Epoch 166/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.1853 - accuracy: 0.9352 - val_loss: 1.9334 - val_accuracy: 0.5806
# Epoch 167/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.1857 - accuracy: 0.9355 - val_loss: 1.8397 - val_accuracy: 0.5672
# Epoch 168/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.1852 - accuracy: 0.9376 - val_loss: 1.7446 - val_accuracy: 0.5852
# Epoch 169/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.1779 - accuracy: 0.9393 - val_loss: 1.9150 - val_accuracy: 0.5890
# Epoch 170/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.1756 - accuracy: 0.9397 - val_loss: 2.1226 - val_accuracy: 0.5748
# Epoch 171/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.1780 - accuracy: 0.9378 - val_loss: 1.9387 - val_accuracy: 0.5772
# Epoch 172/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.1755 - accuracy: 0.9407 - val_loss: 1.9476 - val_accuracy: 0.5766
# Epoch 173/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.1695 - accuracy: 0.9416 - val_loss: 2.1153 - val_accuracy: 0.5320
# Epoch 174/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.1705 - accuracy: 0.9420 - val_loss: 1.9824 - val_accuracy: 0.5817
# Epoch 175/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.1613 - accuracy: 0.9450 - val_loss: 2.0788 - val_accuracy: 0.5769
# Epoch 176/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.1617 - accuracy: 0.9448 - val_loss: 2.1128 - val_accuracy: 0.5823
# Epoch 177/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.1605 - accuracy: 0.9456 - val_loss: 2.0655 - val_accuracy: 0.5764
# Epoch 178/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.1628 - accuracy: 0.9449 - val_loss: 2.2950 - val_accuracy: 0.5494
# Epoch 179/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.1553 - accuracy: 0.9471 - val_loss: 2.2646 - val_accuracy: 0.5808
# Epoch 180/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.1544 - accuracy: 0.9469 - val_loss: 2.2345 - val_accuracy: 0.5900
# Epoch 181/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.1483 - accuracy: 0.9497 - val_loss: 2.2554 - val_accuracy: 0.5732
# Epoch 182/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.1541 - accuracy: 0.9475 - val_loss: 2.2582 - val_accuracy: 0.5861
# Epoch 183/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.1506 - accuracy: 0.9486 - val_loss: 2.3340 - val_accuracy: 0.5647
# Epoch 184/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.1524 - accuracy: 0.9487 - val_loss: 2.0692 - val_accuracy: 0.6101
# Epoch 185/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.1404 - accuracy: 0.9524 - val_loss: 2.0406 - val_accuracy: 0.5805
# Epoch 186/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.1396 - accuracy: 0.9534 - val_loss: 2.1779 - val_accuracy: 0.5693
# Epoch 187/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.1405 - accuracy: 0.9533 - val_loss: 2.3023 - val_accuracy: 0.5676
# Epoch 188/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.1362 - accuracy: 0.9553 - val_loss: 2.2056 - val_accuracy: 0.5704
# Epoch 189/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.1411 - accuracy: 0.9518 - val_loss: 2.5578 - val_accuracy: 0.5675
# Epoch 190/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.1406 - accuracy: 0.9518 - val_loss: 2.4062 - val_accuracy: 0.5796
# Epoch 191/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.1387 - accuracy: 0.9541 - val_loss: 2.3643 - val_accuracy: 0.5347
# Epoch 192/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.1353 - accuracy: 0.9542 - val_loss: 2.3693 - val_accuracy: 0.5807
# Epoch 193/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.1305 - accuracy: 0.9570 - val_loss: 2.2442 - val_accuracy: 0.5749
# Epoch 194/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.1286 - accuracy: 0.9563 - val_loss: 2.6549 - val_accuracy: 0.5821
# Epoch 195/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.1323 - accuracy: 0.9565 - val_loss: 2.4617 - val_accuracy: 0.5727
# Epoch 196/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.1262 - accuracy: 0.9564 - val_loss: 2.2305 - val_accuracy: 0.6033
# Epoch 197/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.1218 - accuracy: 0.9598 - val_loss: 2.7007 - val_accuracy: 0.5652
# Epoch 198/200
# 208/208 [==============================] - 23s 111ms/step - loss: 0.1252 - accuracy: 0.9586 - val_loss: 2.4528 - val_accuracy: 0.5812
# Epoch 199/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.1220 - accuracy: 0.9587 - val_loss: 2.3765 - val_accuracy: 0.5926
# Epoch 200/200
# 208/208 [==============================] - 23s 110ms/step - loss: 0.1183 - accuracy: 0.9599 - val_loss: 2.4627 - val_accuracy: 0.5809

# %%
import matplotlib.pyplot as plt

figure = plt.figure(figsize=(10, 10))
plt.plot(hist_.history['accuracy'], label='Train_accuracy')
plt.plot(hist_.history['val_accuracy'], label='Test_accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc="upper left")
plt.show()

figure2 = plt.figure(figsize=(10, 10))
plt.plot(hist_.history['loss'], label='Train_loss')
plt.plot(hist_.history['val_loss'], label='Test_loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc="upper left")
plt.show()

from sklearn.metrics import classification_report

ypred = model.predict(aug_testing_images)
ypred = np.argmax(ypred, axis=1)
y_test_pred = np.argmax(aug_testing_labels, axis=1)
print(classification_report(y_test_pred, ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.39      0.51      6315
#            1       0.00      0.00      0.00       108
#            2       0.74      0.67      0.71      9698
#            3       0.35      0.67      0.46      4480
#
#     accuracy                           0.58     20601
#    macro avg       0.46      0.43      0.42     20601
# weighted avg       0.66      0.58      0.59     20601
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
